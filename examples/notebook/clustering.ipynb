# %% [markdown]
# # Cell Clustering for sn-Hi-C

# %%
import chr3d as c3d

# %% [markdown]
# ## Set Input Files

# %%
cool_files = {
    'cell_001': '/path/to/cell_001.cool',
    'cell_002': '/path/to/cell_002.cool',
    'cell_003': '/path/to/cell_003.cool'
}
output_dir = './clustering_results'

# %% [markdown]
# ## Run Clustering

# %%
from chr3d.hic.clustering import run_clustering

# %%
run_clustering(
    cool_files=cool_files,
    output_dir=output_dir
)
