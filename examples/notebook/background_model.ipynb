# %% [markdown]
# # Background Model for Loop Calling

# %%
from chr3d.peak_based.background_model import classify_pets, extract_templates

# %% [markdown]
# ## Set Input Files

# %%
bedpe = '/path/to/loops.bedpe'
peaks = '/path/to/peaks.bed'
output_dir = './background_results'

# %% [markdown]
# ## Classify PETs

# %%
classify_pets(
    bedpe_file=bedpe,
    peaks_file=peaks,
    output_dir=output_dir
)

# %% [markdown]
# ## Extract Templates

# %%
extract_templates(
    p2p_file=f'{output_dir}/P2P.bedpe',
    output_file=f'{output_dir}/templates.csv'
)
